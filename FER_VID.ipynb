# %%
from fer import Video

# %%
from fer import FER

# %%
import os

# %%
import sys

# %%
import pandas as pd

# %%
import time

# %% [markdown]
# //add the location of the video

# %%
location_videofile = "vid1.mp4"

# %% [markdown]
# #code for the analysing algo

# %%
face_detector = FER(mtcnn=True)

# %% [markdown]
# #input the video file to processing

# %%
input_video = Video(location_videofile)

# %%
start_time = time.time()

# %%
processing_data = input_video.analyze(face_detector, display=False)
# Out:
#   0%|                                                                                      | 0/138 [00:00<?, ?frames/s]
# 15-12-2021:19:15:31,347 INFO     [classes.py:199] 14.87 fps, 138 frames, 9.28 seconds
# 15-12-2021:19:15:31,348 INFO     [classes.py:207] Making directories at output
# 15-12-2021:19:15:31,348 INFO     [classes.py:352] Deleted pre-existing output\vid1_output.mp4
# 100%|████████████████████████████████████████████████████████████████████████████| 138/138 [03:09<00:00,  1.37s/frames]
# 15-12-2021:19:18:40,523 INFO     [classes.py:320] Completed analysis: saved to output\vid1_output.mp4
# 15-12-2021:19:18:40,524 INFO     [classes.py:327] Starting to Zip
# 15-12-2021:19:18:40,843 INFO     [classes.py:338] Compressing: 62%
# 15-12-2021:19:18:41,21 INFO     [classes.py:339] Zip has finished

# %%
end_time = time.time()

# %%
vid_df = input_video.to_pandas(processing_data)

# %%
vid_df = input_video.get_first_face(vid_df)

# %%
vid_df = input_video.get_emotions(vid_df)

# %%
pltfig = vid_df.plot(figsize=(20,8), fontsize=16).get_figure()

# %%
angry = sum(vid_df.angry)
disgust = sum(vid_df.disgust)
fear = sum(vid_df.fear)
happy = sum(vid_df.happy)
sad = sum(vid_df.sad)
surprise = sum(vid_df.surprise)
neutral = sum(vid_df.neutral)

# %%
emotions = ['Angry', 'Disgust', 'Fear', 'Happy', 'Sad', 'Surprise', 'Neutral']

# %%
emotions_values = [angry, disgust, fear, happy, sad, surprise, neutral]

# %%
score_comparisons = pd.DataFrame(emotions, columns = ['Human Emotions'])

# %%
score_comparisons['Emotion Value from the Video'] = emotions_values

# %%
time_diff = (end_time - start_time)

# %%
print(time_diff)
# Out:
# 205.726149559021

# %%
score_comparisons
# Out:
#   Human Emotions  Emotion Value from the Video
# 0          Angry                          3.23
# 1        Disgust                          0.00
# 2           Fear                          3.34
# 3          Happy                         44.77
# 4            Sad                          2.98
# 5       Surprise                          0.53
# 6        Neutral                         24.96
