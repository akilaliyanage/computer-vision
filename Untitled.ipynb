# %%
from fer import FER
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
test_image_one = plt.imread("./test3.jpg")

# %%
emo_detector = FER(mtcnn=True)

# %%
capture_emortions = emo_detector.detect_emotions(test_image_one)

# %%
print(capture_emortions)
# Out:
# [{'box': (547, 270, 331, 331), 'emotions': {'angry': 0.03, 'disgust': 0.0, 'fear': 0.03, 'happy': 0.01, 'sad': 0.05, 'surprise': 0.0, 'neutral': 0.89}}]

# %%
plt.imshow(test_image_one)

# %%
dominant_emotion, emotion_score = emo_detector.top_emotion(test_image_one)

# %%
print(dominant_emotion, emotion_score)
# Out:
# neutral 0.89
